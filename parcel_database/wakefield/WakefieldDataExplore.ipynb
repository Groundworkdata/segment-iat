# %% [markdown]
# # Wakefield Parcel Data
# Explores Wakefield parcel data and looks for code commonality with work done on Holyoke parcel data
#
# Note that the following column names were added:
# * Property Account Number
# * CONDO_UNIT
# * COMPLEX_NAME
# * OWNER 3
# * UTILITY
# * TRAFFIC
# * ?PERMIT?
# * Number of Buildings (Property Cards)
# * HALF BATHS
# * KITCHENS
# * Building Conditions
# * Fireplaces
# * Solar Hot Water
# * Central Vacuum
# * HEAT TYPE
# * HEAT FUEL
# * PCT_AIR_CONDITIONED
# * BSMT_ALT_FINISH
# * ROOF_COVER
# * ?CURRENT ASSESSMENT?
# * SALES PRICE
# * ARMS Sales
# * GRANTOR LAST NAME
# * BK / PG (2)
# * DATE (2)
# * Sales Price (2)
# * ARMS Sales (2)
# * GRANTOR LAST NAME (2)
# * STATE CODE

# %%
import pandas as pd
import numpy as np

# %%
FILEPATH = "./parcel_wakefield_raw.csv"

# %%
df = pd.read_csv(FILEPATH)

# %%
df
# Out:
#       Unnamed: 0       PCL ID Property Account Number       ST NU      ST ALT  \
# 0              1  07-069-182C                   10006
# 1              2  07-042-184A                   10014          63        -63A
# 2              3  07-036-188A                   10022          31
# 3              4   02-006-20C                    1003
# 4              5  07-038-191A                   10031          27
# ...          ...          ...                     ...         ...         ...
# 9770       10129  19-2M2-206B                   39722           2
# 9771       10130   13-07B-034                   22912           7
# 9772       10131   13-09B-034                   22912           9
# 9773       10132   24-225-82A                   48274        1014
# 9774       10133   24-227-82A                   48274        1014
#
#                                  LOCATION  CONDO_UNIT COMPLEX_NAME  \
# 0     WALNUT ST
# 1     CEDAR ST
# 2     GOULD ST
# 3     PARKER RD
# 4     GOULD ST
# ...                                   ...         ...          ...
# 9770  MIDDLESEX ST                                # 2          212
# 9771  BARTLEY ST                                               213
# 9772  BARTLEY ST                                               213
# 9773  MAIN ST                                      #1          214
# 9774  MAIN ST                                      #2          214
#
#                                                   OWNER  \
# 0     MERULLO, WILLIAM D                            ...
# 1     KLINE, ROBERT A                               ...
# 2     GOLDSTEIN  ALLAN                              ...
# 3     TOWN OF WAKEFIELD                             ...
# 4     PASSERINI, PATRICK A                          ...
# ...                                                 ...
# 9770  KOZACHEK  CATHERINE                           ...
# 9771  FINN  LAUREN & RYAN                           ...
# 9772  YU SYNG M                                     ...
# 9773  NIDEN MATTHEW R                               ...
# 9774  PRINCE IV JOHN LARRACEY                       ...
#
#                                                 OWNER 2  ... Sales Price (2)  \
# 0     WILLIAM J MERULLO                             ...  ...               0
# 1                                                        ...          210000
# 2     DADY-GOLDSTEIN  DIANE M                       ...  ...          333000
# 3     BOARD OF SELECTMEN                            ...  ...               0
# 4     JOYCE K PASSERINI                             ...  ...           64000
# ...                                                 ...  ...             ...
# 9770  VERTOPI  JETMIR                               ...  ...               1
# 9771                                                     ...               1
# 9772  YU BRITTANY K                                 ...  ...               1
# 9773  OMO NICOLETTA S                               ...  ...               1
# 9774  HILL JEFFERY PHILIP                           ...  ...               1
#
#      ARMS Sales (2)                              GRANTOR LAST NAME (2)  \
# 0                    KEHOE                                         ...
# 1      CONVERSION    BARRETT                                       ...
# 2                    LEDONNE,RICHARD M                             ...
# 3
# 4                 3  BERTRAND                                      ...
# ...             ...                                                ...
# 9770   CONVENIENCE   TWO MIDDLESEX STREET LLC ,                    ...
# 9771   CONVENIENCE   JDR REALTY INVESTMENTS LLC,                   ...
# 9772   CONVENIENCE   JDR REALTY INVESTMENTS LLC,                   ...
# 9773   CONVENIENCE   PHAN,KY Q                                     ...
# 9774   CONVENIENCE   PHAN,KY Q                                     ...
#
#      LAND VAL YARD ITEMS BUILD VAL TOTAL VAL  \
# 0       42000      14700         0     56700
# 1      255500          0    402100    657600
# 2      254000       3700    212800    470500
# 3      153500          0         0    153500
# 4      255300          0    251800    507100
# ...       ...        ...       ...       ...
# 9770        0          0    550600    550600
# 9771        0          0    628300    628300
# 9772        0          0    778600    778600
# 9773        0          0    473300    473300
# 9774        0          0    483900    483900
#
#                                             Unnamed: 80    ADJ AREA  \
# 0                                                   ...
# 1                                                   ...        5461
# 2                                                   ...      2359.2
# 3                                                   ...
# 4                                                   ...        2963
# ...                                                 ...         ...
# 9770                                                ...        3186
# 9771                                                ...        2757
# 9772                                                ...        3878
# 9773                                                ...        1970
# 9774                                                ...        2035
#
#                                     STATE CODE
# 0                             F_769337_3008027
# 1                             F_769446_3007971
# 2                             F_769416_3007700
# 3                             F_766364_3011614
# 4                             F_769530_3007727
# ...                                        ...
# 9770                          F_774102_3006007
# 9771                          F_770501_3006591
# 9772                          F_770501_3006591
# 9773
# 9774
#
# [9775 rows x 83 columns]

# %%
cols_to_keep = [i for i in df.columns if i.find("Unnamed: ") == -1]

# %%
df = df[cols_to_keep]

# %%
df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)

# %%
df
# Out:
#            PCL ID Property Account Number ST NU ST ALT      LOCATION  \
# 0     07-069-182C                   10006                  WALNUT ST
# 1     07-042-184A                   10014    63   -63A      CEDAR ST
# 2     07-036-188A                   10022    31             GOULD ST
# 3      02-006-20C                    1003                  PARKER RD
# 4     07-038-191A                   10031    27             GOULD ST
# ...           ...                     ...   ...    ...           ...
# 9770  19-2M2-206B                   39722     2         MIDDLESEX ST
# 9771   13-07B-034                   22912     7           BARTLEY ST
# 9772   13-09B-034                   22912     9           BARTLEY ST
# 9773   24-225-82A                   48274  1014              MAIN ST
# 9774   24-227-82A                   48274  1014              MAIN ST
#
#      CONDO_UNIT COMPLEX_NAME                    OWNER  \
# 0                                  MERULLO, WILLIAM D
# 1                                     KLINE, ROBERT A
# 2                                    GOLDSTEIN  ALLAN
# 3                                   TOWN OF WAKEFIELD
# 4                                PASSERINI, PATRICK A
# ...         ...          ...                      ...
# 9770        # 2          212      KOZACHEK  CATHERINE
# 9771                     213      FINN  LAUREN & RYAN
# 9772                     213                YU SYNG M
# 9773         #1          214          NIDEN MATTHEW R
# 9774         #2          214  PRINCE IV JOHN LARRACEY
#
#                       OWNER 2 OWNER 3  ...   DATE (2) Sales Price (2)  \
# 0           WILLIAM J MERULLO          ...  12/3/1953               0
# 1                                      ...   1/8/1990          210000
# 2     DADY-GOLDSTEIN  DIANE M          ...  6/25/2010          333000
# 3          BOARD OF SELECTMEN          ...                          0
# 4           JOYCE K PASSERINI          ...  8/17/1981           64000
# ...                       ...     ...  ...        ...             ...
# 9770          VERTOPI  JETMIR          ...  3/18/2019               1
# 9771                                   ...  4/28/2020               1
# 9772            YU BRITTANY K          ...  4/28/2020               1
# 9773          OMO NICOLETTA S          ...  5/13/2020               1
# 9774      HILL JEFFERY PHILIP          ...  5/13/2020               1
#
#      ARMS Sales (2)        GRANTOR LAST NAME (2) LAND VAL YARD ITEMS  \
# 0                                          KEHOE    42000      14700
# 1        CONVERSION                      BARRETT   255500          0
# 2                              LEDONNE,RICHARD M   254000       3700
# 3                                                  153500          0
# 4                 3                     BERTRAND   255300          0
# ...             ...                          ...      ...        ...
# 9770    CONVENIENCE   TWO MIDDLESEX STREET LLC ,        0          0
# 9771    CONVENIENCE  JDR REALTY INVESTMENTS LLC,        0          0
# 9772    CONVENIENCE  JDR REALTY INVESTMENTS LLC,        0          0
# 9773    CONVENIENCE                    PHAN,KY Q        0          0
# 9774    CONVENIENCE                    PHAN,KY Q        0          0
#
#      BUILD VAL  TOTAL VAL ADJ AREA        STATE CODE
# 0            0      56700           F_769337_3008027
# 1       402100     657600     5461  F_769446_3007971
# 2       212800     470500   2359.2  F_769416_3007700
# 3            0     153500           F_766364_3011614
# 4       251800     507100     2963  F_769530_3007727
# ...        ...        ...      ...               ...
# 9770    550600     550600     3186  F_774102_3006007
# 9771    628300     628300     2757  F_770501_3006591
# 9772    778600     778600     3878  F_770501_3006591
# 9773    473300     473300     1970
# 9774    483900     483900     2035
#
# [9775 rows x 67 columns]

# %%
df.to_csv("parcel_wakefield_raw_cleaned.csv", index=False)

# %% [markdown]
# ## Calculate values of note

# %%
FILEPATH = "./parcel_wakefield_raw_cleaned.csv"

# %%
df = pd.read_csv(FILEPATH)
# Out:
# /Users/conorlyman/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (1,6) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df.iloc[:, 1]
# Out:
# 0       10006.0
# 1       10014.0
# 2       10022.0
# 3        1003.0
# 4       10031.0
#          ...
# 9770      39722
# 9771      22912
# 9772      22912
# 9773      48274
# 9774      48274
# Name: Property Account Number, Length: 9775, dtype: object

# %%
df.iloc[:, 6]
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 9770    212
# 9771    213
# 9772    213
# 9773    214
# 9774    214
# Name: COMPLEX_NAME, Length: 9775, dtype: object

# %%
def get_number_of_units(_x):
    floor_area = _x["FLA"]
    num_kitchens = _x["KITCHENS"]
    
    if num_kitchens > 0 and floor_area > 0:
        return num_kitchens
    return 0

# %%
df["Number of units"] = df.apply(get_number_of_units, axis=1)

# %%
df
# Out:
#            PCL ID Property Account Number ST NU ST ALT      LOCATION  \
# 0     07-069-182C                 10006.0   NaN    NaN     WALNUT ST
# 1     07-042-184A                 10014.0    63   -63A      CEDAR ST
# 2     07-036-188A                 10022.0    31    NaN      GOULD ST
# 3      02-006-20C                  1003.0   NaN    NaN     PARKER RD
# 4     07-038-191A                 10031.0    27    NaN      GOULD ST
# ...           ...                     ...   ...    ...           ...
# 9770  19-2M2-206B                   39722     2    NaN  MIDDLESEX ST
# 9771   13-07B-034                   22912     7    NaN    BARTLEY ST
# 9772   13-09B-034                   22912     9    NaN    BARTLEY ST
# 9773   24-225-82A                   48274  1014    NaN       MAIN ST
# 9774   24-227-82A                   48274  1014    NaN       MAIN ST
#
#      CONDO_UNIT COMPLEX_NAME                    OWNER  \
# 0           NaN          NaN       MERULLO, WILLIAM D
# 1           NaN          NaN          KLINE, ROBERT A
# 2           NaN          NaN         GOLDSTEIN  ALLAN
# 3           NaN          NaN        TOWN OF WAKEFIELD
# 4           NaN          NaN     PASSERINI, PATRICK A
# ...         ...          ...                      ...
# 9770        # 2          212      KOZACHEK  CATHERINE
# 9771        NaN          213      FINN  LAUREN & RYAN
# 9772        NaN          213                YU SYNG M
# 9773         #1          214          NIDEN MATTHEW R
# 9774         #2          214  PRINCE IV JOHN LARRACEY
#
#                       OWNER 2 OWNER 3  ... Sales Price (2) ARMS Sales (2)  \
# 0           WILLIAM J MERULLO     NaN  ...               0            NaN
# 1                         NaN     NaN  ...          210000     CONVERSION
# 2     DADY-GOLDSTEIN  DIANE M     NaN  ...          333000            NaN
# 3          BOARD OF SELECTMEN     NaN  ...               0            NaN
# 4           JOYCE K PASSERINI     NaN  ...           64000              3
# ...                       ...     ...  ...             ...            ...
# 9770          VERTOPI  JETMIR     NaN  ...               1    CONVENIENCE
# 9771                      NaN     NaN  ...               1    CONVENIENCE
# 9772            YU BRITTANY K     NaN  ...               1    CONVENIENCE
# 9773          OMO NICOLETTA S     NaN  ...               1    CONVENIENCE
# 9774      HILL JEFFERY PHILIP     NaN  ...               1    CONVENIENCE
#
#             GRANTOR LAST NAME (2) LAND VAL YARD ITEMS  BUILD VAL  TOTAL VAL  \
# 0                           KEHOE    42000      14700          0      56700
# 1                         BARRETT   255500          0     402100     657600
# 2               LEDONNE,RICHARD M   254000       3700     212800     470500
# 3                             NaN   153500          0          0     153500
# 4                        BERTRAND   255300          0     251800     507100
# ...                           ...      ...        ...        ...        ...
# 9770   TWO MIDDLESEX STREET LLC ,        0          0     550600     550600
# 9771  JDR REALTY INVESTMENTS LLC,        0          0     628300     628300
# 9772  JDR REALTY INVESTMENTS LLC,        0          0     778600     778600
# 9773                    PHAN,KY Q        0          0     473300     473300
# 9774                    PHAN,KY Q        0          0     483900     483900
#
#       ADJ AREA        STATE CODE  Number of units
# 0          NaN  F_769337_3008027                0
# 1       5461.0  F_769446_3007971                3
# 2       2359.2  F_769416_3007700                1
# 3          NaN  F_766364_3011614                0
# 4       2963.0  F_769530_3007727                1
# ...        ...               ...              ...
# 9770    3186.0  F_774102_3006007                1
# 9771    2757.0  F_770501_3006591                1
# 9772    3878.0  F_770501_3006591                1
# 9773    1970.0               NaN                1
# 9774    2035.0               NaN                1
#
# [9775 rows x 68 columns]

# %%
def get_heat_system(_x):
    mapping = {
        None: None,
        "STEAM": "STEAM",
        "FORCED H/A": "DUCTED",
        "FORCED H/W": "NON-DUCTED",
        "UNIT HTRS": "NON-DUCTED",
        "ELECTRC BB": "NON-DUCTED",
        "RADIANT HW": "NON-DUCTED",
        "GRAVTY H/A": "NON-DUCTED",
        "FLOOR FURN": "NON-DUCTED",
        "NOT DUCTED": "NON-DUCTED",
        "AVERAGE": "NON-DUCTED",
        "WALL UNIT": "NON-DUCTED",
    }
    
    return mapping.get(_x["HEAT TYPE"])

# %%
df["Heat system"] = df.apply(get_heat_system, axis=1)

# %%
df
# Out:
#            PCL ID Property Account Number ST NU ST ALT      LOCATION  \
# 0     07-069-182C                 10006.0   NaN    NaN     WALNUT ST
# 1     07-042-184A                 10014.0    63   -63A      CEDAR ST
# 2     07-036-188A                 10022.0    31    NaN      GOULD ST
# 3      02-006-20C                  1003.0   NaN    NaN     PARKER RD
# 4     07-038-191A                 10031.0    27    NaN      GOULD ST
# ...           ...                     ...   ...    ...           ...
# 9770  19-2M2-206B                   39722     2    NaN  MIDDLESEX ST
# 9771   13-07B-034                   22912     7    NaN    BARTLEY ST
# 9772   13-09B-034                   22912     9    NaN    BARTLEY ST
# 9773   24-225-82A                   48274  1014    NaN       MAIN ST
# 9774   24-227-82A                   48274  1014    NaN       MAIN ST
#
#      CONDO_UNIT COMPLEX_NAME                    OWNER  \
# 0           NaN          NaN       MERULLO, WILLIAM D
# 1           NaN          NaN          KLINE, ROBERT A
# 2           NaN          NaN         GOLDSTEIN  ALLAN
# 3           NaN          NaN        TOWN OF WAKEFIELD
# 4           NaN          NaN     PASSERINI, PATRICK A
# ...         ...          ...                      ...
# 9770        # 2          212      KOZACHEK  CATHERINE
# 9771        NaN          213      FINN  LAUREN & RYAN
# 9772        NaN          213                YU SYNG M
# 9773         #1          214          NIDEN MATTHEW R
# 9774         #2          214  PRINCE IV JOHN LARRACEY
#
#                       OWNER 2 OWNER 3  ... ARMS Sales (2)  \
# 0           WILLIAM J MERULLO     NaN  ...            NaN
# 1                         NaN     NaN  ...     CONVERSION
# 2     DADY-GOLDSTEIN  DIANE M     NaN  ...            NaN
# 3          BOARD OF SELECTMEN     NaN  ...            NaN
# 4           JOYCE K PASSERINI     NaN  ...              3
# ...                       ...     ...  ...            ...
# 9770          VERTOPI  JETMIR     NaN  ...    CONVENIENCE
# 9771                      NaN     NaN  ...    CONVENIENCE
# 9772            YU BRITTANY K     NaN  ...    CONVENIENCE
# 9773          OMO NICOLETTA S     NaN  ...    CONVENIENCE
# 9774      HILL JEFFERY PHILIP     NaN  ...    CONVENIENCE
#
#             GRANTOR LAST NAME (2) LAND VAL YARD ITEMS BUILD VAL  TOTAL VAL  \
# 0                           KEHOE    42000      14700         0      56700
# 1                         BARRETT   255500          0    402100     657600
# 2               LEDONNE,RICHARD M   254000       3700    212800     470500
# 3                             NaN   153500          0         0     153500
# 4                        BERTRAND   255300          0    251800     507100
# ...                           ...      ...        ...       ...        ...
# 9770   TWO MIDDLESEX STREET LLC ,        0          0    550600     550600
# 9771  JDR REALTY INVESTMENTS LLC,        0          0    628300     628300
# 9772  JDR REALTY INVESTMENTS LLC,        0          0    778600     778600
# 9773                    PHAN,KY Q        0          0    473300     473300
# 9774                    PHAN,KY Q        0          0    483900     483900
#
#       ADJ AREA        STATE CODE  Number of units  Heat system
# 0          NaN  F_769337_3008027                0         None
# 1       5461.0  F_769446_3007971                3        STEAM
# 2       2359.2  F_769416_3007700                1       DUCTED
# 3          NaN  F_766364_3011614                0         None
# 4       2963.0  F_769530_3007727                1   NON-DUCTED
# ...        ...               ...              ...          ...
# 9770    3186.0  F_774102_3006007                1       DUCTED
# 9771    2757.0  F_770501_3006591                1       DUCTED
# 9772    3878.0  F_770501_3006591                1       DUCTED
# 9773    1970.0               NaN                1       DUCTED
# 9774    2035.0               NaN                1       DUCTED
#
# [9775 rows x 69 columns]

# %%
building_type_mapping_file = "../database/mappings/building_type_mapping.csv"
df_build_type_mapping = pd.read_csv(building_type_mapping_file)

# %%
df_build_type_mapping
# Out:
#           DESC      Building Type
# 0   PMP/VLV HS             Office
# 1     2 FAMILY  Small Multifamily
# 2      4-8 FAM  Large Residential
# 3     3 FAMILY  Small Multifamily
# 4   APRTMNT-GN  Large Residential
# ..         ...                ...
# 79   SUPER MKT        Supermarket
# 80  NIGHT CLUB          Resturant
# 81  BOWLING AL           Assembly
# 82        RINK           Assembly
# 83    POST OFF             Retail
#
# [84 rows x 2 columns]

# %%
mapping_dict = df_build_type_mapping.set_index("DESC").to_dict()["Building Type"]

# %%
def set_building_type(_x, mapping_dict):
    return mapping_dict.get(_x["DESC"])

# %%
df["Building Type"] = df.apply(set_building_type, axis=1, args=(mapping_dict,))

# %%
df
# Out:
#            PCL ID Property Account Number ST NU ST ALT      LOCATION  \
# 0     07-069-182C                 10006.0   NaN    NaN     WALNUT ST
# 1     07-042-184A                 10014.0    63   -63A      CEDAR ST
# 2     07-036-188A                 10022.0    31    NaN      GOULD ST
# 3      02-006-20C                  1003.0   NaN    NaN     PARKER RD
# 4     07-038-191A                 10031.0    27    NaN      GOULD ST
# ...           ...                     ...   ...    ...           ...
# 9770  19-2M2-206B                   39722     2    NaN  MIDDLESEX ST
# 9771   13-07B-034                   22912     7    NaN    BARTLEY ST
# 9772   13-09B-034                   22912     9    NaN    BARTLEY ST
# 9773   24-225-82A                   48274  1014    NaN       MAIN ST
# 9774   24-227-82A                   48274  1014    NaN       MAIN ST
#
#      CONDO_UNIT COMPLEX_NAME                    OWNER  \
# 0           NaN          NaN       MERULLO, WILLIAM D
# 1           NaN          NaN          KLINE, ROBERT A
# 2           NaN          NaN         GOLDSTEIN  ALLAN
# 3           NaN          NaN        TOWN OF WAKEFIELD
# 4           NaN          NaN     PASSERINI, PATRICK A
# ...         ...          ...                      ...
# 9770        # 2          212      KOZACHEK  CATHERINE
# 9771        NaN          213      FINN  LAUREN & RYAN
# 9772        NaN          213                YU SYNG M
# 9773         #1          214          NIDEN MATTHEW R
# 9774         #2          214  PRINCE IV JOHN LARRACEY
#
#                       OWNER 2 OWNER 3  ...        GRANTOR LAST NAME (2)  \
# 0           WILLIAM J MERULLO     NaN  ...                        KEHOE
# 1                         NaN     NaN  ...                      BARRETT
# 2     DADY-GOLDSTEIN  DIANE M     NaN  ...            LEDONNE,RICHARD M
# 3          BOARD OF SELECTMEN     NaN  ...                          NaN
# 4           JOYCE K PASSERINI     NaN  ...                     BERTRAND
# ...                       ...     ...  ...                          ...
# 9770          VERTOPI  JETMIR     NaN  ...   TWO MIDDLESEX STREET LLC ,
# 9771                      NaN     NaN  ...  JDR REALTY INVESTMENTS LLC,
# 9772            YU BRITTANY K     NaN  ...  JDR REALTY INVESTMENTS LLC,
# 9773          OMO NICOLETTA S     NaN  ...                    PHAN,KY Q
# 9774      HILL JEFFERY PHILIP     NaN  ...                    PHAN,KY Q
#
#      LAND VAL YARD ITEMS BUILD VAL TOTAL VAL  ADJ AREA        STATE CODE  \
# 0       42000      14700         0     56700       NaN  F_769337_3008027
# 1      255500          0    402100    657600    5461.0  F_769446_3007971
# 2      254000       3700    212800    470500    2359.2  F_769416_3007700
# 3      153500          0         0    153500       NaN  F_766364_3011614
# 4      255300          0    251800    507100    2963.0  F_769530_3007727
# ...       ...        ...       ...       ...       ...               ...
# 9770        0          0    550600    550600    3186.0  F_774102_3006007
# 9771        0          0    628300    628300    2757.0  F_770501_3006591
# 9772        0          0    778600    778600    3878.0  F_770501_3006591
# 9773        0          0    473300    473300    1970.0               NaN
# 9774        0          0    483900    483900    2035.0               NaN
#
#       Number of units  Heat system  Building Type
# 0                   0         None           None
# 1                   3        STEAM           None
# 2                   1       DUCTED           None
# 3                   0         None           None
# 4                   1   NON-DUCTED           None
# ...               ...          ...            ...
# 9770                1       DUCTED           None
# 9771                1       DUCTED           None
# 9772                1       DUCTED           None
# 9773                1       DUCTED           None
# 9774                1       DUCTED           None
#
# [9775 rows x 70 columns]

# %%
# Some building DESCs are not included in the mapping... do we need to update the mapping?
df[df["Building Type"].isnull() & df["DESC"]]["DESC"]
# Out:
# 1        FAMILY FLAT
# 2        DUTCH COLON
# 4       N E COLONIAL
# 5           CAPE COD
# 7           CAPE COD
#             ...
# 9770    CONDEX CONDO
# 9771    CONDEX CONDO
# 9772    CONDEX CONDO
# 9773    CONVER CONDO
# 9774    CONVER CONDO
# Name: DESC, Length: 6277, dtype: object

# %%
# Need to update the mapping
mapping_2 = pd.read_csv("../database/mappings/building_type_mapping_2.csv")

# %%
df_build_type_mapping = df_build_type_mapping.set_index("DESC")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/q4/7911fbv57wv3c68srp1cdlkm0000gn/T/ipykernel_33559/2814475792.py in <module>
# ----> 1 df_build_type_mapping = df_build_type_mapping.set_index("DESC")
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    5449
#    5450         if missing:
# -> 5451             raise KeyError(f"None of {missing} are in the columns")
#    5452
#    5453         if inplace:
#
# KeyError: "None of ['DESC'] are in the columns"

# %%
mapping_2 = mapping_2.applymap(lambda x: x.strip() if isinstance(x, str) else x)
mapping_2 = mapping_2.set_index("DESC")

# %%
df_build_type_mapping["Building Type"]
# Out:
# DESC
# PMP/VLV HS               Office
# 2 FAMILY      Small Multifamily
# 4-8 FAM       Large Residential
# 3 FAMILY      Small Multifamily
# APRTMNT-GN    Large Residential
#                     ...
# SUPER MKT           Supermarket
# NIGHT CLUB            Resturant
# BOWLING AL             Assembly
# RINK                   Assembly
# POST OFF                 Retail
# Name: Building Type, Length: 84, dtype: object

# %%
mapping_2
# Out:
#                   Building Type
# DESC
# FAMILY FLAT   Small Multifamily
# DUTCH COLON       Single Family
# N E COLONIAL      Single Family
# CAPE COD          Single Family
# COLONIAL          Single Family
# ...                         ...
# MOBL HOME         Single Family
# DORMITORY     Large Residential
# INDUST CONDO         Industrial
# PRE ENG MF            Warehouse
# CONDO         Large Residential
#
# [79 rows x 1 columns]

# %%
pd.merge(df_build_type_mapping, mapping_2, how="inner", on="DESC")
# Out:
#               Building Type_x    Building Type_y
# DESC
# STORE                  Retail             Retail
# COMM BLOCK          Warehouse             Office
# COLONIAL        Single Family      Single Family
# WAREHOUSE           Warehouse             Garage
# RANCH           Single Family      Single Family
# ANTIQUE         Single Family      Single Family
# DORMITORY   Large Residential  Large Residential
# BUNGALOW        Single Family  Small Multifamily
# RESTAURANT          Resturant         Restaurant
# FUNERAL HM             Retail             Office
# HOTEL                   Hotel              Hotel
# MILL               Industrial          Warehouse
# SPLIT CAPE      Single Family      Single Family
# BOWLING AL           Assembly           Assembly

# %%
# So there is some overlap, with a few discrepancies... we will need to address

# %%
full_mapping = pd.concat([df_build_type_mapping, mapping_2])
full_mapping.to_csv("../database/mappings/full_building_type_mappings.csv")
full_mapping = full_mapping.to_dict()["Building Type"]

# %%
df.loc[[1, 2, 3], :].apply(set_building_type, axis=1, args=(full_mapping,))
# Out:
# FAMILY FLAT
# Small Multifamily
# DUTCH COLON
# Single Family
# nan
# None
# 1    Small Multifamily
# 2        Single Family
# 3                 None
# dtype: object

# %%
df["Building Type"] = df.apply(set_building_type, axis=1, args=(full_mapping,))

# %%
df
# Out:
#            PCL ID Property Account Number ST NU ST ALT      LOCATION  \
# 0     07-069-182C                 10006.0   NaN    NaN     WALNUT ST
# 1     07-042-184A                 10014.0    63   -63A      CEDAR ST
# 2     07-036-188A                 10022.0    31    NaN      GOULD ST
# 3      02-006-20C                  1003.0   NaN    NaN     PARKER RD
# 4     07-038-191A                 10031.0    27    NaN      GOULD ST
# ...           ...                     ...   ...    ...           ...
# 9770  19-2M2-206B                   39722     2    NaN  MIDDLESEX ST
# 9771   13-07B-034                   22912     7    NaN    BARTLEY ST
# 9772   13-09B-034                   22912     9    NaN    BARTLEY ST
# 9773   24-225-82A                   48274  1014    NaN       MAIN ST
# 9774   24-227-82A                   48274  1014    NaN       MAIN ST
#
#      CONDO_UNIT COMPLEX_NAME                    OWNER  \
# 0           NaN          NaN       MERULLO, WILLIAM D
# 1           NaN          NaN          KLINE, ROBERT A
# 2           NaN          NaN         GOLDSTEIN  ALLAN
# 3           NaN          NaN        TOWN OF WAKEFIELD
# 4           NaN          NaN     PASSERINI, PATRICK A
# ...         ...          ...                      ...
# 9770        # 2          212      KOZACHEK  CATHERINE
# 9771        NaN          213      FINN  LAUREN & RYAN
# 9772        NaN          213                YU SYNG M
# 9773         #1          214          NIDEN MATTHEW R
# 9774         #2          214  PRINCE IV JOHN LARRACEY
#
#                       OWNER 2 OWNER 3  ... LAND VAL YARD ITEMS BUILD VAL  \
# 0           WILLIAM J MERULLO     NaN  ...    42000      14700         0
# 1                         NaN     NaN  ...   255500          0    402100
# 2     DADY-GOLDSTEIN  DIANE M     NaN  ...   254000       3700    212800
# 3          BOARD OF SELECTMEN     NaN  ...   153500          0         0
# 4           JOYCE K PASSERINI     NaN  ...   255300          0    251800
# ...                       ...     ...  ...      ...        ...       ...
# 9770          VERTOPI  JETMIR     NaN  ...        0          0    550600
# 9771                      NaN     NaN  ...        0          0    628300
# 9772            YU BRITTANY K     NaN  ...        0          0    778600
# 9773          OMO NICOLETTA S     NaN  ...        0          0    473300
# 9774      HILL JEFFERY PHILIP     NaN  ...        0          0    483900
#
#      TOTAL VAL ADJ AREA        STATE CODE  Number of units  Heat system  \
# 0        56700      NaN  F_769337_3008027                0         None
# 1       657600   5461.0  F_769446_3007971                3        STEAM
# 2       470500   2359.2  F_769416_3007700                1       DUCTED
# 3       153500      NaN  F_766364_3011614                0         None
# 4       507100   2963.0  F_769530_3007727                1   NON-DUCTED
# ...        ...      ...               ...              ...          ...
# 9770    550600   3186.0  F_774102_3006007                1       DUCTED
# 9771    628300   2757.0  F_770501_3006591                1       DUCTED
# 9772    778600   3878.0  F_770501_3006591                1       DUCTED
# 9773    473300   1970.0               NaN                1       DUCTED
# 9774    483900   2035.0               NaN                1       DUCTED
#
#           Building Type  Decade Built
# 0                  None           NaN
# 1     Small Multifamily        1930.0
# 2         Single Family        1910.0
# 3                  None           NaN
# 4         Single Family        1900.0
# ...                 ...           ...
# 9770  Small Multifamily        2010.0
# 9771  Small Multifamily        2010.0
# 9772  Small Multifamily        2010.0
# 9773  Small Multifamily        1900.0
# 9774  Small Multifamily        1900.0
#
# [9775 rows x 71 columns]

# %%
df["Decade Built"] = ((df["YEAR BLT"].fillna(0) // 10) * 10).astype(int).replace(0, np.nan)

# %%
df.to_csv("./parcel_wakefield_final.csv", index=False)
